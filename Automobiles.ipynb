# %% [markdown]
# # 🚗 **Exploratory Data Analysis (EDA) of Car Data** 🚗

# %% [markdown]
# ### Introduction
#
# The Automobiles Dataset is a comprehensive collection of data pertaining to various attributes of automobiles. It provides valuable insights into the features and specifications of different cars, facilitating analysis and understanding of the automotive industry. The dataset is compiled to assist researchers, analysts, and enthusiasts in exploring patterns, correlations, and trends within the automotive domain. The data encompasses a wide range of characteristics, allowing for a detailed examination of factors influencing automobile performance, cost, and market dynamics.

# %% [markdown]
# ### Features of the Dataset
#
# 1. **Symboling**: Represents the insurance risk rating of the vehicle, which provides an assessment of its safety and risk.
#
# 2. **Normalized-losses**: Denotes the normalized losses in terms of insurance claims for each vehicle, providing insights into their risk factor.
#
# 3. **Make**: Specifies the manufacturer or brand of the automobile, indicating the company responsible for its production.
#
# 4. **Fuel-type**: Indicates the type of fuel used by the vehicle, such as gasoline or diesel.
#
# 5. **Aspiration**: Represents whether the automobile is naturally aspirated or equipped with forced induction.
#
# 6. **Num-of-doors**: Specifies the number of doors on the vehicle, a feature significant for both functionality and aesthetics.
#
# 7. **Body-style**: Describes the general shape and style of the vehicle, such as sedan, hatchback, coupe, etc.
#
# 8. **Drive-wheels**: Indicates the type of wheels that provide power to the vehicle, influencing its handling and performance.
#
# 9. **Engine-location**: Identifies the placement of the engine, which can be either front or rear, impacting the vehicle's weight distribution and handling.
#
# 10. **Wheel-base, Length, Width, Height**: These dimensions provide physical measurements of the vehicle, aiding in assessing its size and proportions.
#
# 11. **Curb-weight**: Represents the weight of the vehicle without occupants or cargo, a crucial factor in determining its performance and fuel efficiency.
#
# 12. **Engine-type**: Denotes the type of engine used in the vehicle, such as 'dohc', 'ohcv', etc.
#
# 13. **Num-of-cylinders**: Specifies the number of cylinders in the vehicle's engine, influencing its power and efficiency.
#
# 14. **Engine-size**: Represents the volume of the engine's combustion chambers, affecting the power and performance of the vehicle.
#
# 15. **Fuel-system**: Describes the type of fuel injection system in the vehicle, which impacts its fuel delivery and efficiency.
#
# 16. **Bore, Stroke, Compression-ratio**: These parameters pertain to the engine's internal combustion characteristics, affecting its efficiency and power output.
#
# 17. **Horsepower, Peak-rpm**: Indicate the engine's horsepower and peak revolutions per minute, providing information about its power and performance.
#
# 18. **City-mpg, Highway-mpg**: Represent the miles per gallon (mpg) of fuel efficiency in city and highway driving, respectively.
#
# 19. **Price**: Specifies the cost of the automobile, a crucial factor for market analysis and consumer decision-making.
#
# Understanding and analyzing these features can yield valuable insights into the automotive industry, helping in predicting vehicle performance, assessing market trends, and making informed business and consumer decisions.

# %% [markdown]
# ##### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings as warn
pd.set_option('display.max_columns',None)
warn.simplefilter(action='ignore', category=FutureWarning)
sns.set_style('darkgrid')

# %% [markdown]
# ##### Upload Dataset

# %%
cars = pd.read_csv('automobiles.csv')
cars.head()
# Out:
#    symboling  normalized-losses  make fuel-type aspiration num-of-doors  \
# 0          2                164  audi       gas        std         four
# 1          2                164  audi       gas        std         four
# 2          1                158  audi       gas        std         four
# 3          1                158  audi       gas      turbo         four
# 4          2                192   bmw       gas        std          two
#
#   body-style drive-wheels engine-location  wheel-base  length  width  height  \
# 0      sedan          fwd           front        99.8   176.6   66.2    54.3
# 1      sedan          4wd           front        99.4   176.6   66.4    54.3
# 2      sedan          fwd           front       105.8   192.7   71.4    55.7
# 3      sedan          fwd           front       105.8   192.7   71.4    55.9
# 4      sedan          rwd           front       101.2   176.8   64.8    54.3
#
# ...

# %% [markdown]
# #### Structure of Data

# %%
f"No of Rows: {cars.shape[0]} & No of Columns : {cars.shape[1]}"
# Out:
# 'No of Rows: 159 & No of Columns : 26'

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          159 non-null    int64
#  1   normalized-losses  159 non-null    int64
#  2   make               159 non-null    object
#  3   fuel-type          159 non-null    object
#  4   aspiration         159 non-null    object
#  5   num-of-doors       159 non-null    object
#  6   body-style         159 non-null    object
#  7   drive-wheels       159 non-null    object
#  8   engine-location    159 non-null    object
#  9   wheel-base         159 non-null    float64
#  10  length             159 non-null    float64
#  11  width              159 non-null    float64
#  12  height             159 non-null    float64
#  13  curb-weight        159 non-null    int64
#  14  engine-type        159 non-null    object
#  15  num-of-cylinders   159 non-null    object
# ...

# %% [markdown]
# #### Missing Values

# %%
cars.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %% [markdown]
# No mission value found

# %% [markdown]
# #### Statistic Summary of Numeric Features

# %%
cars.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  159.000000         159.000000  159.000000  159.000000  159.000000
# mean     0.735849         121.132075   98.264151  172.413836   65.607547
# std      1.193086          35.651285    5.167416   11.523177    1.947883
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  165.650000   64.000000
# 50%      1.000000         113.000000   96.900000  172.400000   65.400000
# 75%      2.000000         148.000000  100.800000  177.800000   66.500000
# max      3.000000         256.000000  115.600000  202.600000   71.700000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  159.000000   159.000000   159.000000  159.000000  159.000000
# mean    53.899371  2461.138365   119.226415    3.300126    3.236352
# std      2.268761   481.941321    30.460791    0.267336    0.294888
# ...

# %% [markdown]
# #### Statistic Summary of Categoric Features

# %%
cars.describe(include='object')
# Out:
#           make fuel-type aspiration num-of-doors body-style drive-wheels  \
# count      159       159        159          159        159          159
# unique      18         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        31       144        132           95         79          105
#
#        engine-location engine-type num-of-cylinders fuel-system
# count              159         159              159         159
# unique               1           5                5           6
# top              front         ohc             four        mpfi
# freq               159         123              136          64

# %% [markdown]
# #### Distribution of Target Feature

# %%
cars['price'].describe().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(cars.price)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.boxplot(y=cars.price,orient='v')
# Out:
# <AxesSubplot:ylabel='price'>

# %% [markdown]
# ### Conclusion
# Based on the provided code using seaborn's `distplot` &  `boxplot`  functions to visualize the distribution of automobile prices, the following conclusion can be drawn:
#
# The distribution plot of automobile prices indicates that the majority of the cars have prices clustered within a certain range between aprox 7000 to 15000 , with a peak in the distribution. This suggests that a significant portion of the automobiles have prices concentrated in a specific price range. However, there are also notable outliers on the higher end of the price spectrum, indicating the presence of luxury or high-value vehicles in the dataset. Further analysis and exploration of the distribution will provide a more detailed understanding of the price distribution and potential insights into the automobile market.

# %% [markdown]
# ## Relationship between Numeric Features with `Price`

# %%
cars.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.518344   -0.520591 -0.336257
# normalized-losses   0.518344           1.000000   -0.060086  0.035541
# wheel-base         -0.520591          -0.060086    1.000000  0.871534
# length             -0.336257           0.035541    0.871534  1.000000
# width              -0.219186           0.109726    0.814991  0.838338
# height             -0.475185          -0.413702    0.555767  0.499251
# curb-weight        -0.251880           0.125858    0.810181  0.871291
# engine-size        -0.109453           0.207820    0.649206  0.725953
# bore               -0.256469          -0.031558    0.578159  0.646318
# stroke             -0.021285           0.063330    0.167449  0.121073
# compression-ratio  -0.138316          -0.127259    0.291431  0.184814
# horsepower         -0.003949           0.290511    0.516948  0.672063
# ...

# %% [markdown]
# #### Relationship with Target variable

# %%
cars.corr()['price']
# Out:
# symboling           -0.162794
# normalized-losses    0.202761
# wheel-base           0.734419
# length               0.760952
# width                0.843371
# height               0.244836
# curb-weight          0.893639
# engine-size          0.841496
# bore                 0.533890
# stroke               0.160664
# compression-ratio    0.209361
# horsepower           0.759874
# peak-rpm            -0.171916
# city-mpg            -0.692273
# highway-mpg         -0.720090
# price                1.000000
# Name: price, dtype: float64

# %%
corr_mat = cars.corr()['price'][abs(cars.corr()['price'])>.7]
corr_df =pd.DataFrame(data=corr_mat
                       .values,
                      index=corr_mat
                      .index,
                      columns=['corr_values'])
corr_df
# Out:
#              corr_values
# wheel-base      0.734419
# length          0.760952
# width           0.843371
# curb-weight     0.893639
# engine-size     0.841496
# horsepower      0.759874
# highway-mpg    -0.720090
# price           1.000000

# %%
g=corr_df.plot(kind='barh')
g.set_title('Price corelation')
# Out:
# Text(0.5, 1.0, 'Price corelation')

# %%
sns.heatmap(cars[corr_df.index].corr(), 
            annot=True,
            cmap='RdBu', 
            center =0,
            vmin=-1,
            vmax=1,
            linewidths=1
                   )
plt.show()

# %% [markdown]
# ### Conclusion
# From the above heatmap, `wheel-base`, `length`,`width`,`curb-weight`,`engine-size`and `horsepower` are highly **+ve** correlated with `price`.<br>
# and `highway-mpg` is highly **-ve** correlated with `price`.

# %%
g=sns.jointplot(x=cars['wheel-base'],
              y=cars['price'],
              ylim=(0,40000))

# %% [markdown]
# ### Conclusion
# The above plot clearly shows a linear relationship between ‘price’ and ‘wheel-base’. The ‘price’ increases with an increase in ‘wheel-base’.

# %% [markdown]
# Now let's consider the relationship amoung price with `length`,`width`,`curb-weight`,`engine-size`and `horsepower` which are highly **+ve** correlated with `price`

# %%
g=sns.JointGrid()
sns.regplot(x=cars['length'],
            y=cars['price'], 
            ax=g.ax_joint)
sns.kdeplot(x=cars['length'],
            ax=g.ax_marg_x)
sns.kdeplot(y=cars['price'],
            ax=g.ax_marg_y)
# Out:
# <AxesSubplot:xlabel='Density', ylabel='price'>

# %%
# g=sns.jointplot(x=cars['width'],
#               y=cars['price'],
#               ylim=(0,40000))
g=sns.JointGrid()
sns.regplot(x=cars['width'],
            y=cars['price'], 
            ax=g.ax_joint)
sns.histplot(x=cars['width'],
            ax=g.ax_marg_x)
sns.histplot(y=cars['price'],
            ax=g.ax_marg_y)
g.ax_joint.set_ylim(0, 40000)
# Out:
# (0.0, 40000.0)

# %%
g=sns.jointplot(x=cars['curb-weight'],
              y=cars['price'],
              ylim=(0,40000))

# %%
g=sns.jointplot(x=cars['engine-size'],
              y=cars['price'],
              ylim=(0,40000))

# %%
g=sns.jointplot(x=cars['horsepower'],
              y=cars['price'],
              ylim=(0,40000))

# %% [markdown]
# ### Conclusion
# Observe the data trend: there is a noticeable positive linear relationship between price and the variables `length`, `width`, `curb-weight`, `engine-size`, and `horsepower`, showing a strong positive correlation.

# %%
g=sns.jointplot(x=cars['highway-mpg'],
              y=cars['price'],
              ylim=(0,40000))

# %% [markdown]
# ### Conclusion
# There is a direct **-ve** linear relationship between `highway`-mpg and `price`.

# %% [markdown]
# ## Relationship Pattern between Categorical Features and `Price`

# %%
sns.countplot(y='make', 
              data=cars,
              order= cars.make
              .value_counts()
              .index )
plt.show()

# %% [markdown]
# ### Conclusion
# Referencing the plot above, it is evident that Toyota, Nissan, Honda, Subaru, and Mazda are the top five car manufacturers producing the highest number of cars.

# %%
g=sns.catplot(kind='bar', 
              y='make',
              x='price', 
              data=cars,
              order = cars.groupby('make')['price']
              .mean().sort_values(ascending=False).index,
              ci=None)
g.set_xticklabels(rotation=90)
plt.show()

# %%
g=sns.catplot(data=cars,
           kind='strip', 
           x='make',
           y='price',
           jitter=False,
           palette='Paired',
           order=cars.groupby('make')['price']
           .mean().sort_values(ascending=False).index,
           alpha=1)
g.set_xticklabels(rotation=90)

# %% [markdown]
# ### Conclusion
# Upon observing the above plots, it is evident that, although Jaguar, Mercedes, Porsche, BMW, and Audi are the top five car manufacturers that produce fewer cars but with the higher prices.

# %%
# makers = cars.groupby('make')['price'].mean().sort_values(ascending=False).index
# cars['makers_ord']=cars['make'].replace({elem:num for num,elem in zip(range(len(makers)),makers)})
# cars['makers_ord'].shape

# %%
g=sns.JointGrid()
sns.barplot(data=cars, x='fuel-type',
            y='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, x='fuel-type',
            ax=g.ax_marg_x)
sns.histplot(data=cars, y='price',
            ax=g.ax_marg_y)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion
# We can observe a trend: most manufacturers produce cars with gasoline fuel type, while fewer produce diesel cars. The latter tend to have slightly higher prices, although it's not very significant.

# %%
g=sns.JointGrid()
sns.scatterplot(data=cars, x='fuel-system',
            y='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, x='fuel-system',
            ax=g.ax_marg_x)
sns.histplot(data=cars, y='price',
            ax=g.ax_marg_y)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion
# We can follow the pattern: most car makers prefer **mpfi**, **2bbl**, or idi fuel systems in car manufacturing. Additionally, it's noticeable that **mpfi** and **idi** could be a factor contributing to higher prices.

# %%
g=sns.JointGrid()
sns.scatterplot(data=cars, x='num-of-cylinders',
            y='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, x='num-of-cylinders',
            ax=g.ax_marg_x)
sns.histplot(data=cars, y='price',
            ax=g.ax_marg_y)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion
# We can observe a pattern: the num-of-cylinders is one of the most influential factors that increases car prices when the number of cylinders is increase.

# %%
g=sns.JointGrid()
sns.scatterplot(data=cars, x='engine-type',
            y='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, x='engine-type',
            ax=g.ax_marg_x)
sns.histplot(data=cars, y='price',
            ax=g.ax_marg_y)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion:
# This visual analysis of the relationship between the engine type ('engine-type') and the price ('price') of cars for different manufacturers ('make'). The plot provides a comparison of how the engine type influences the price across various car makes.

# %%
g=sns.JointGrid()
sns.barplot(data=cars, x='drive-wheels',
            y='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, x='drive-wheels',
            ax=g.ax_marg_x)
sns.kdeplot(data=cars, y='price',
            ax=g.ax_marg_y)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion
# We could cearly see that, the **rwd drive-wheels system** is one of the most influential factors in raising car prices.

# %%
g=sns.JointGrid()
sns.barplot(data=cars, x='num-of-doors',
            y='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, x='num-of-doors',
            ax=g.ax_marg_x)
sns.kdeplot(data=cars, y='price',
            ax=g.ax_marg_y)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion:
#
# We could cearly observe that, the **num-of-doors** are not much play a major role in raising car prices up.

# %%
g=sns.JointGrid()
sns.barplot(data=cars, y='aspiration',
            x='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, y='aspiration',
            ax=g.ax_marg_y)
sns.kdeplot(data=cars, x='price',
            ax=g.ax_marg_x)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion:
# We could cearly observe that, The `aspiration` feature is not much play a major role in raising car prices up.

# %%
g=sns.JointGrid()
sns.scatterplot(data=cars, y='body-style',
            x='price',
            hue='make',
            ax=g.ax_joint,
            ci=None)
sns.histplot(data=cars, y='body-style',
            ax=g.ax_marg_y)
sns.histplot(data=cars, x='price',
            ax=g.ax_marg_x)

g.ax_joint.legend(bbox_to_anchor=(1.25, .99), loc='upper left')

# %% [markdown]
# ### Conclusion:
# The `'body-style'` feature is not much play a major role in raising car prices up.
